# %%
import pandas as pd

# %%
import pandas as pd

# %%
import pandas as pd
edvisits=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx\EDVisits')
edvisits
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6392/2792409288.py in <module>
#       1 import pandas as pd
# ----> 2 edvisits=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx\EDVisits')
#       3 edvisits
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
edvisits=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"EDVisits")

# %%
edvisits
# Out:
#       EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 0             1          1 2020-01-01 00:00:00.000 2020-01-01 11:20:22.924
# 1            12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 2            13         13 2020-01-01 03:09:24.701 2020-01-01 05:00:20.852
# 3            14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 4            15         15 2020-01-01 03:46:32.698 2020-01-01 06:24:52.741
# ...         ...        ...                     ...                     ...
# 1194       1183        929 2020-01-15 10:38:42.570 2020-01-16 02:31:52.023
# 1195       1186        932 2020-01-15 11:52:37.540 2020-01-16 10:19:41.570
# 1196       1187        933 2020-01-15 12:11:11.678 2020-01-15 16:41:15.223
# 1197       1188        934 2020-01-15 12:21:46.006 2020-01-15 18:32:21.060
# 1198       1189        935 2020-01-15 12:51:14.875 2020-01-15 23:40:41.456
#
#       Acuity ReasonForVisit EDDisposition
# ...

# %%
df.head()
# Out:
#    EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 0          1          1 2020-01-01 00:00:00.000 2020-01-01 11:20:22.924
# 1         12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 2         13         13 2020-01-01 03:09:24.701 2020-01-01 05:00:20.852
# 3         14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 4         15         15 2020-01-01 03:46:32.698 2020-01-01 06:24:52.741
#
#    Acuity ReasonForVisit EDDisposition
# 0       1   Stomach Ache      Admitted
# 1       2       Migraine      Admitted
# 2       3   Stomach Ache      Admitted
# 3       3       Migraine      Admitted
# 4       3     Chest Pain      Admitted

# %%
import numpy as np

# %%
import datetime
from dateutil.relativedelta import relativedelta

# %%
from datetime import date

# %%
edvisits['diff_hours']=edvisits['EDDischargeTime']-edvisits['Visitdate']
edvisits['diff_hours']=edvisits['diff_hours']/np.timedelta64(1,'h')
print(edvisits)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Visitdate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
1.

# %% [markdown]
# # 1.Calculate

# %%
edvisits['diff_hours']=edvisits['EDDischargeTime']-edvisits['VisitDate']
edvisits['diff_hours']=edvisits['diff_hours']/np.timedelta64(1,'h')
print(edvisits)
# Out:
#       EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 0             1          1 2020-01-01 00:00:00.000 2020-01-01 11:20:22.924
# 1            12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 2            13         13 2020-01-01 03:09:24.701 2020-01-01 05:00:20.852
# 3            14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 4            15         15 2020-01-01 03:46:32.698 2020-01-01 06:24:52.741
# ...         ...        ...                     ...                     ...
# 1194       1183        929 2020-01-15 10:38:42.570 2020-01-16 02:31:52.023
# 1195       1186        932 2020-01-15 11:52:37.540 2020-01-16 10:19:41.570
# 1196       1187        933 2020-01-15 12:11:11.678 2020-01-15 16:41:15.223
# 1197       1188        934 2020-01-15 12:21:46.006 2020-01-15 18:32:21.060
# 1198       1189        935 2020-01-15 12:51:14.875 2020-01-15 23:40:41.456
#
#       Acuity ReasonForVisit EDDisposition  diff_hours
# ...

# %%
df['diff_hours']=df['EDDischargeTime']-df['VisitDate']
df['diff_hours']=df['diff_hours']/np.timedelta64(1,'h')
print(round(df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34252/2688890904.py in <module>
# ----> 1 df['diff_hours']=df['EDDischargeTime']-df['VisitDate']
#       2 df['diff_hours']=df['diff_hours']/np.timedelta64(1,'h')
#       3 print(round(df))
#
# NameError: name 'df' is not defined

# %%
#Q2:Get the number of patients based on service and primary diagnosis
readmissionregistry=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"ReAdmissionRegistry")

# %%
readmissionregistry
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0            389          1    2018-01-01 2018-01-04 19:59:31.391
# 1            635          2    2018-01-01 2018-01-04 21:28:51.898
# 2            606          3    2018-01-01 2018-01-04 22:28:23.672
# 3            587          5    2018-01-01 2018-01-05 05:47:04.933
# 4            640          6    2018-01-01 2018-01-05 14:18:30.029
# ..           ...        ...           ...                     ...
# 715          521        738    2018-02-22 2018-03-07 21:22:10.061
# 716          548        739    2018-02-22 2018-03-08 02:43:18.749
# 717          509        740    2018-02-22 2018-03-08 09:27:18.377
# 718          605        741    2018-02-22 2018-03-10 06:06:12.068
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#     DischargeDisposition           Service PrimaryDiagnosis  ExpectedLOS  \
# 0                   Home       Hospitalist   Kidney Failure     6.717771
# ...

# %%
#g=readmissionregistry.groupby(['Service','PrimaryDiagnosis'])['PatientID'].count()
readmissionregistry.groupby(['Service','PrimaryDiagnosis']).agg(count_Of_Patients=('PatientID','count'))
# Out:
#                                      count_Of_Patients
# Service          PrimaryDiagnosis
# Cardiology       AMI                                40
#                  Afib                               10
#                  Broken Leg                          3
#                  Flu                                 2
#                  Heart Failure                      39
#                  Kidney Failure                      1
# General Medicine Broken Leg                          3
#                  Diabetes                           38
#                  Fever                              13
#                  Flu                                54
#                  Hypertension                       35
#                  Kidney Failure                     12
#                  Laceration                         21
#                  Pneumonia                          67
#                  Stroke                             20
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#       EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 0             1          1 2020-01-01 00:00:00.000 2020-01-01 11:20:22.924
# 1            12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 2            13         13 2020-01-01 03:09:24.701 2020-01-01 05:00:20.852
# 3            14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 4            15         15 2020-01-01 03:46:32.698 2020-01-01 06:24:52.741
# ...         ...        ...                     ...                     ...
# 1194       1183        929 2020-01-15 10:38:42.570 2020-01-16 02:31:52.023
# 1195       1186        932 2020-01-15 11:52:37.540 2020-01-16 10:19:41.570
# 1196       1187        933 2020-01-15 12:11:11.678 2020-01-15 16:41:15.223
# 1197       1188        934 2020-01-15 12:21:46.006 2020-01-15 18:32:21.060
# 1198       1189        935 2020-01-15 12:51:14.875 2020-01-15 23:40:41.456
#
#       Acuity ReasonForVisit EDDisposition  diff_hours
# ...

# %%
sns.pairplot(df,hue='EDDisposition',size=2.5)
# Out:
# C:\Users\harin\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df,hue='EDDisposition')

# %% [markdown]
# #5.Create a bar chart between expectedLOS & Primary diagnosis

# %%
x=readmissionregistry['ExpectedLOS']
y=readmissionregistry['PrimaryDiagnosis']
plt.bar(x,y,label='Hospital Dataset',color='Red')
plt.xlabel('ExpectedLOS')
plt.ylabel('PrimaryDiagnosis')
plt.show()

# %%
y=readmissionregistry['ExpectedLOS']
x=readmissionregistry['PrimaryDiagnosis']
plt.bar(x,y,width=0.3,label='Hospital Dataset',color='Red')
plt.ylabel('ExpectedLOS')
plt.xlabel('PrimaryDiagnosis')
plt.xticks(rotation='vertical')
plt.show()

# %%
df
# Out:
#       EDVisitID  PatientID               VisitDate         EDDischargeTime  \
# 0             1          1 2020-01-01 00:00:00.000 2020-01-01 11:20:22.924
# 1            12         12 2020-01-01 02:45:40.302 2020-01-02 02:00:00.517
# 2            13         13 2020-01-01 03:09:24.701 2020-01-01 05:00:20.852
# 3            14         14 2020-01-01 03:12:19.349 2020-01-01 04:32:29.142
# 4            15         15 2020-01-01 03:46:32.698 2020-01-01 06:24:52.741
# ...         ...        ...                     ...                     ...
# 1194       1183        929 2020-01-15 10:38:42.570 2020-01-16 02:31:52.023
# 1195       1186        932 2020-01-15 11:52:37.540 2020-01-16 10:19:41.570
# 1196       1187        933 2020-01-15 12:11:11.678 2020-01-15 16:41:15.223
# 1197       1188        934 2020-01-15 12:21:46.006 2020-01-15 18:32:21.060
# 1198       1189        935 2020-01-15 12:51:14.875 2020-01-15 23:40:41.456
#
#       Acuity ReasonForVisit EDDisposition  diff_hours
# ...

# %%
df.set_index('ID')
   .stack()
   .groupby['ReasonForVisit','EDDisposition']
   .value_counts()
   .unstack(fill_value=0)
# Out:
#   File "C:\Users\harin\AppData\Local\Temp/ipykernel_29792/1718845094.py", line 2
#     .stack()
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # 12.create a visulization on the count of patients based on primary diagnosis

# %%
cntp=readmissionregistry.groupby(['PrimaryDiagnosis']).agg(count_Of_Patients=('PatientID','count'))

# %%
cntp
# Out:
#                     count_Of_Patients
# PrimaryDiagnosis
# AMI                                48
# Afib                               11
# Broken Leg                          9
# Diabetes                           64
# Fever                              19
# Flu                                80
# Heart Failure                      78
# Hip Fracture                       23
# Hypertension                       50
# Kidney Failure                     20
# Knee Replacement                   23
# Laceration                         29
# Migraine                           12
# Pain                                7
# Pneumonia                         177
# Spinal Cord Injury                  2
# Stroke                             68

# %%
ax = cntp.plot.bar(figsize=(6,4), width=0.2)
ax.bar_label(ax.containers[0], label_type='edge')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # Q13 Create a bar chart on service and expected length of stay

# %%
y=readmissionregistry['ExpectedLOS']
x=readmissionregistry['Service']
plt.bar(x,y,width=0.3,label='Hospital Dataset',color='Red')
plt.ylabel('ExpectedLOS')
plt.xlabel('Service')
plt.xticks(rotation='vertical')
plt.show()

# %%
patients=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"Patients")

# %%
patients
# Out:
#      PatientID FirstName  LastName             DateOfBirth Gender  \
# 0            1     Lanni       Sue 1960-01-01 00:00:00.000   Male
# 1            2       Far     Myers 1985-11-15 02:08:42.090   Male
# 2            3   Devlin    Michael 1976-04-15 02:52:09.762   Male
# 3            4   Carmine     Texas 1968-10-15 03:32:13.635   Male
# 4            5     Tann       Bama 1962-05-01 19:12:58.950   Male
# ..         ...       ...       ...                     ...    ...
# 940        941       Wat   Fideler 1986-05-26 00:01:19.761   Male
# 941        942    Wandie  Baythrop 1970-06-10 21:41:03.814   Male
# 942        943   Diahann   Smeeton 1983-01-08 21:49:27.884   Male
# 943        944  Panchito   Sharple 1963-06-05 07:57:05.569   Male
# 944        945     Walsh    Calvie 1972-08-06 03:40:03.454   Male
#
#                        Race Language
# 0                     White  English
# 1                     White  English
# 2                     White  English
# ...

# %%
patients[(patients['Language']=='Spanish')].agg(count_Of_Patients=('PatientID','count'))
# Out:
#                    PatientID
# count_Of_Patients        110

# %%
readmissionregistry.boxplot(column='ExpectedLOS', by='Service')
plt.title('')
plt.suptitle('')
plt.xticks(rotation='vertical')
# Out:
# (array([1, 2, 3, 4, 5, 6]),
#  [Text(1, 0, 'Cardiology'),
#   Text(2, 0, 'General Medicine'),
#   Text(3, 0, 'Hospitalist'),
#   Text(4, 0, 'ICU'),
#   Text(5, 0, 'Neurology'),
#   Text(6, 0, 'Orthopeadics')])

# %%
discharges=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"Discharges")

# %%
discharges
# Out:
#      AdmissionID  PatientID AdmissionDate           DischargeDate  \
# 0              1          9    2018-01-01 2018-01-07 18:06:06.408
# 1            257         93    2018-01-06 2018-01-18 02:59:04.667
# 2            152        101    2018-01-07 2018-01-11 16:16:06.782
# 3            361        102    2018-01-07 2018-01-15 04:48:33.134
# 4            258        103    2018-01-07 2018-01-15 13:32:36.157
# ..           ...        ...           ...                     ...
# 715          715        716    2018-02-21 2018-03-06 03:31:05.262
# 716          698        723    2018-02-22 2018-02-26 15:09:02.584
# 717          704        724    2018-02-22 2018-02-27 07:59:32.385
# 718          716        733    2018-02-22 2018-03-05 12:31:55.958
# 719          710        742    2018-02-22 2018-03-10 20:38:30.568
#
#     DischargeDisposition           Service PrimaryDiagnosis  ExpectedLOS  \
# 0                Expired        Cardiology              AMI     9.646857
# ...

# %%
sns.boxplot(x='Service',y='ExpectedLOS',readmissionregistry)
# Out:
#   File "C:\Users\harin\AppData\Local\Temp/ipykernel_29792/2370285232.py", line 1
#     sns.boxplot(x='Service',y='ExpectedLOS',readmissionregistry)
#                                                                ^
# SyntaxError: positional argument follows keyword argument

# %%
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29792/2395499409.py in <module>
# ----> 1 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
Providers=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"Providers")

# %%
Providers
# Out:
#     ProviderID     ProviderName ProviderSpecialty     ProviderDateOnStaff
# 0            1        Sally Sue        Pediatrics 1993-01-01 00:00:00.000
# 1            2       Mike Myers        Pediatrics 1993-05-02 00:00:17.695
# 2            3   Jordan Michael        Pediatrics 1993-06-24 21:31:46.687
# 3            4        Ted Texas        Pediatrics 1993-12-23 21:33:52.299
# 4            5         Ala Bama        Pediatrics 1995-01-10 02:53:47.838
# 5            6       Harry Kane        Pediatrics 1995-07-21 03:49:03.310
# 6            7        Barry Bar        Pediatrics 1995-11-21 19:30:38.759
# 7            8        Ted Green        Pediatrics 1996-05-30 06:14:52.539
# 8            9        Ted Black        Pediatrics 1997-02-20 08:01:10.211
# 9           10         Fred Man           Surgery 1998-03-17 01:47:18.794
# 10          11     Kim Kimberly           Surgery 1998-05-10 14:47:29.468
# 11          12         Sarah Ab           Surgery 1998-08-18 05:22:40.762
# ...

# %%
fig=px.sunburst(Providers,)

# %%
  
fig = px.sunburst(df, path=['ProviderName', 'Providerspeciality'], 
                  values='providerDateOnStaff')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29792/2254670531.py in <module>
#       1 df = px.data.tips()
#       2
# ----> 3 fig = px.sunburst(df, path=['ProviderName', 'Providerspeciality'],
#       4                   values='providerDateOnStaff')
#       5 fig.show()
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539     if path is not None and branchvalues is None:
#    1540         branchvalues = "total"
# -> 1541     return make_figure(
#    1542         args=locals(),
#    1543         constructor=go.Sunburst,
#
# ...

# %%
fig = px.sunburst(Providers, path=['ProviderName'], 
                  values='ProviderDateOnStaff')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29792/1620538505.py in <module>
# ----> 1 fig = px.sunburst(Providers, path=['ProviderName', 'Providerspeciality'],
#       2                   values='ProviderDateOnStaff')
#       3 fig.show()
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539     if path is not None and branchvalues is None:
#    1540         branchvalues = "total"
# -> 1541     return make_figure(
#    1542         args=locals(),
#    1543         constructor=go.Sunburst,
#
# ...

# %%
fig = px.sunburst(Providers, path=['ProviderName','ProviderSpecialty'], 
                  values='ProviderDateOnStaff')
fig.show()
# Out:
# <div>                            <div id="b7709013-efbc-41ba-90f3-c6f29911492d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7709013-efbc-41ba-90f3-c6f29911492d")) {                    Plotly.newPlot(                        "b7709013-efbc-41ba-90f3-c6f29911492d",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>ProviderDateOnStaff=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Bailey Barret/Cardiology","Joesph Walter/Cardiology","Kent Kendall/Cardiology","Luke Long/Cardiology","Megan Bonco/Cardiology","Ryan Kevin/Cardiology","Tyler Conner/Cardiology","Walter King/Cardiology","Ala Bama/Pediatrics","Barry Bar/Pediatrics","Harry Kane/Pediatrics","Jordan Mich
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6392/1375011285.py in <module>
# ----> 1 conn=sqlite3.connect('Provider_SQL.db')
#       2 Providers=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"Providers")
#
# NameError: name 'sqlite3' is not defined

# %%
conn=sql.connect('Provider_SQL.db')
Providers=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"Providers")
Providers.to_sql('Providers',conn,if_exists='replace',index=False)
cur=conn.cursor()
select_all="select * from Providers where ProviderName LIKE 'T%'"
rows=cur.execute(select_all).fetchall()
for r in rows:
    print(r)
    conn.close()
# Out:
# (4, 'Ted Texas', 'Pediatrics', '1993-12-23 21:33:52.299000')
# (8, 'Ted Green', 'Pediatrics', '1996-05-30 06:14:52.539000')
# (9, 'Ted Black', 'Pediatrics', '1997-02-20 08:01:10.211000')
# (19, 'Tyler Conner', 'Cardiology', '2003-07-09 02:41:40.410000')
# (34, 'Tony Creed', 'PrimaryCare', '2010-04-28 14:11:26.802000')
# (37, 'Trent Tye', 'PrimaryCare', '2013-01-12 15:32:21.137000')

# %%
ambulatoryvisits=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"AmbulatoryVisits")

# %%
ambulatoryvisits
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit           DateScheduled  \
# 0        202         840          29  2019-03-19 2019-03-13 07:59:24.000
# 1        436         820          25  2019-03-19 2019-02-24 07:10:31.043
# 2        794         879          30  2019-04-02 2019-03-19 01:41:55.656
# 3        799         884          37  2019-03-03 2019-02-25 01:25:39.696
# 4        515          32          26  2019-03-16 2019-02-20 06:44:59.617
# ..       ...         ...         ...         ...                     ...
# 945      788         873           1  2019-03-27 2019-03-10 17:19:48.264
# 946      703         855          36  2019-03-12 2019-02-19 02:27:52.664
# 947      481         865          13  2019-05-03 2019-04-25 13:37:57.501
# 948      398         635          10  2019-02-09 2019-02-08 11:40:35.137
# 949      695         847          24  2019-03-04 2019-02-05 05:29:30.587
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# ...

# %%
conn=sql.connect('AmbulatoryVisits_SQL.db')
import datetime
ambulatoryvisits=pd.read_excel('D:\Kusuma\HospitalDatabase.xlsx',"AmbulatoryVisits")
ambulatoryvisits.to_sql('ambulatoryvisits',conn,if_exists='replace',index=False)
cur=conn.cursor()
select_all= "select strftime('%Y',DateofVisit) as Year from ambulatoryvisits" 
rows=cur.execute(select_all).fetchall()
for r in rows:
   print(r)
   conn.close()
# Out:
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ('2019',)
# ...

# %%
select_all="select * from Providers where ProviderName LIKE 'T%'"

# %%
conn=sql.connect('AmbulatoryVisits_SQL.db')

# %%
Providers['ProviderDateOnStaff']=pd.to_datetime(Providers['ProviderDateOnStaff'],format='%m/%d/%Y %I:%M:%S %p')
Providers['Experience']=pd.to_datetime('today')-Providers['ProviderDateOnStaff']  
fig=px.sunburst(Providers,path=['ProviderName','ProviderSpecialty'],values='Experience')
fig.show()
# Out:
# <div>                            <div id="9a3c27c3-e1ba-41c0-9e60-e5e253b9c977" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a3c27c3-e1ba-41c0-9e60-e5e253b9c977")) {                    Plotly.newPlot(                        "9a3c27c3-e1ba-41c0-9e60-e5e253b9c977",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Experience=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Bailey Barret/Cardiology","Joesph Walter/Cardiology","Kent Kendall/Cardiology","Luke Long/Cardiology","Megan Bonco/Cardiology","Ryan Kevin/Cardiology","Tyler Conner/Cardiology","Walter King/Cardiology","Ala Bama/Pediatrics","Barry Bar/Pediatrics","Harry Kane/Pediatrics","Jordan Michael/Pedia
# ...

# %%
patients
# Out:
#      PatientID FirstName  LastName             DateOfBirth Gender  \
# 0            1     Lanni       Sue 1960-01-01 00:00:00.000   Male
# 1            2       Far     Myers 1985-11-15 02:08:42.090   Male
# 2            3   Devlin    Michael 1976-04-15 02:52:09.762   Male
# 3            4   Carmine     Texas 1968-10-15 03:32:13.635   Male
# 4            5     Tann       Bama 1962-05-01 19:12:58.950   Male
# ..         ...       ...       ...                     ...    ...
# 940        941       Wat   Fideler 1986-05-26 00:01:19.761   Male
# 941        942    Wandie  Baythrop 1970-06-10 21:41:03.814   Male
# 942        943   Diahann   Smeeton 1983-01-08 21:49:27.884   Male
# 943        944  Panchito   Sharple 1963-06-05 07:57:05.569   Male
# 944        945     Walsh    Calvie 1972-08-06 03:40:03.454   Male
#
#                        Race Language
# 0                     White  English
# 1                     White  English
# 2                     White  English
# ...

# %%
y=patients[(patients['Language']=='English')].agg(count_Of_Patients=('PatientID','count'))
x=patients[(patients['Language']=='Spanish')].agg(count_Of_Patients=('PatientID','count'))
plt.bar(x,y,width=0.3,label='Hospital Dataset',color='Red')
plt.ylabel('English')
plt.xlabel('Spanish')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6392/2485045654.py in <module>
#       1 y=patients[(patients['Language']=='English')].agg(count_Of_Patients=('PatientID','count'))
#       2 x=patients[(patients['Language']=='Spanish')].agg(count_Of_Patients=('PatientID','count'))
# ----> 3 plt.bar(x,y,width=0.3,label='Hospital Dataset',color='Red')
#       4 plt.ylabel('English')
#       5 plt.xlabel('Spanish')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2649         x, height, width=0.8, bottom=None, *, align='center',
#    2650         data=None, **kwargs):
# -> 2651     return gca().bar(
#    2652         x, height, width=width, bottom=bottom, align=align,
#    2653         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
S=patients[(patients['Language']=='Spanish')].agg(count_Of_Patients=('PatientID','count'))

# %%
E=patients[(patients['Language']=='English')].agg(count_Of_Patients=('PatientID','count'))

# %%
sns.barplot(x = 'S',
            y = 'E',
            data = patients,
            palette = "Blues")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6392/1120968411.py in <module>
# ----> 1 sns.barplot(x = 'S',
#       2             y = 'E',
#       3             data = patients,
#       4             palette = "Blues")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...

# %% [markdown]
# # Q1 Plot a graph to show count of  male and femlae patients in our dataset

# %%
import matplotlib.pyplot as plt
patients1=patients.groupby('Gender')['PatientID'].count()
ax = patients1.plot.bar(figsize=(6,4), width=0.2,color=['r','b'])
ax.bar_label(ax.containers[0], label_type='edge')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %% [markdown]
# # Q2 Find the count of English Speaking patients

# %%
import re

# %%
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
if x:
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# YES! We have a match!

# %%
patients
x=re.search("La",patients['FirstName'])
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6392/3100287448.py in <module>
#       1 patients
# ----> 2 x=re.search("La",patients['FirstName'])
#       3 print(x)
#
# ~\anaconda3\lib\re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1681785985846' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;ds&#47;dsahbord_Task2_1&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='dsahbord_Task2_1&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;ds&#47;dsahbord_Task2_1&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1681785985846');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1620px';vizElement.style.minHeight='587px';vizElement.style.maxHeight='887px';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1620px';vizElement.style.minHeight='587px';vizElement.style.maxHeight='887px';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';} else { vizElement.style.width='100%';vizElement.style.height='2027px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1681785985846' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;ds&#47;dsahbord_Task2_1&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='dsahbord_Task2_1&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;ds&#47;dsahbord_Task2_1&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param na
# ...
